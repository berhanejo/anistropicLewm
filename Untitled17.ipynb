# %% [markdown]
# <a href="https://colab.research.google.com/github/berhanejo/anistropicLewm/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/lucas-maes/le-wm.git
# Out:
# Cloning into 'le-wm'...
# remote: Enumerating objects: 106, done.
# remote: Total 106 (delta 0), reused 0 (delta 0), pack-reused 106 (from 1)
# Receiving objects: 100% (106/106), 5.28 MiB | 19.50 MiB/s, done.
# Resolving deltas: 100% (57/57), done.
